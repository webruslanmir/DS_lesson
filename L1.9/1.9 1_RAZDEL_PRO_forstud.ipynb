# %% [markdown]
# # Итоговый проект.

# %% [markdown]
# Анализ личности клиента — это подробный анализ клиентов компании. Он помогает компании лучше понять своих клиентов и облегчает изменение продукции в соответствии со специфическими потребностями, поведением различных типов клиентов.
#
# Анализ личности клиента помогает компании модифицировать свой продукт в соответствии с целевыми потребителями из различных сегментов потребителей. Например, вместо того, чтобы тратить деньги на маркетинг нового продукта для каждого клиента в базе данных компании, компания может проанализировать, какой сегмент клиентов с наибольшей вероятностью купит продукт, и затем продвигать продукт только для этого сегмента.
#
# Описание столбцов:
#
# |Название| Описание |
# |--|--|
# |ID| Уникальный идентификатор клиента|
# |Year_Birth| Год рождения клиента|
# |Education | Уровень образования клиента|
# |Marital_Status| Семейное положение клиента|
# |Income| Годовой доход семьи клиента|
# |Kidhome| Количество детей в семье клиента|
# |Teenhome| Количество подростков в домохозяйстве клиента|
# |Dt_Customer| Дата регистрации клиента в компании|
# |Recency| Количество дней с момента последней покупки клиента|
# |Complain| 1, если клиент жаловался в течение последних 2 лет, 0 —  в противном случае|
# |MntWines|  Сумма, потраченная на вино за последние 2 года|
# |MntFruits| Сумма, потраченная на фрукты за последние 2 года|
# |MntMeatProducts| Сумма, потраченная на мясо за последние 2 года|
# |MntFishProducts| Сумма, потраченная на рыбу за последние 2 года|
# |MntSweetProducts| Сумма, потраченная на сладости за последние 2 года|
# |MntGoldProds| Сумма, потраченная на золото за последние 2 года|
# |NumDealsPurchases| Количество покупок, совершенных со скидкой|
# |AcceptedCmp1| 1, если клиент принял предложение в 1-й кампании, 0 — иначе|
# |AcceptedCmp2| 1, если клиент принял предложение во 2-й компании, 0 — иначе|
# |AcceptedCmp3| 1, если клиент принял предложение в 3-й кампании, 0 — иначе|
# |AcceptedCmp4| 1, если клиент принял предложение в 4-й кампании, 0 — иначе|
# |AcceptedCmp5| 1, если клиент принял предложение в 5-й кампании, 0 — иначе|
# |Response| 1, если клиент принял предложение в последней кампании, 0 — иначе|
# |NumWebPurchases| Количество покупок, совершенных через веб-сайт компании|
# |NumCatalogPurchases| Количество покупок, сделанных с помощью каталога|
# |NumStorePurchases| Количество покупок, сделанных непосредственно в магазинах|
# |NumWebVisitsMonth| Количество посещений веб-сайта компании за последний месяц|

# %% [markdown]
# ## Задание
#
# Проведите полный цикл анализа данных (EDA), что проходили ранее. Этапы выполнения задания (наш pipeline):
#
# 1. Загрузка и предобработка данных. Очистить данные и удалить/заполнить пропуски.
# 2. Описательный анализ данных, просмотр данных и вывод статистик
# 3. Постройте необходимые графики для анализа
# 4. Проверьте гипотезы
# 5. Сделайте отчет-вывод по исследованию
#
# Что хочет узнать заказчик?
#
# 1. Сколько в среднем клиенты тратят на каждый тип товара? На какой товар надо сделать акцент?
# 2. Какой средний возраст покупателя? Зависит ли возраст клиента от его покупок во всех категориях?
# 3. Тратят ли клиент больше денег, если у него много детей и иждивенцев?
# 4. Зависят ли покупки от образования? Что предпочитают люди чаще покупать в зависимости от образования?
# 5. Женатые люди тратят больше или меньше денег на покупку золота?
# 6. Люди, которые покупают товар на сайте чаще берут что-то со скидкой?
# 7. Зависит ли жалоба клиента от его трат?
# 8. Люди, принявшие предложение о покупке лишь в последней компании тратят больше, чем люди, принявшие сразу предложение первой компании?
#
# **ЗАДАНИЕ ПРО**
#
# 1. Разбейте данные на несколько выборок: по образованию, по уровню заработка и по семейному статусу. Опишите все эти выборки и скажите — отличаются ли они между собой? Опишите общие закономерности для каждого типа — на что чаще тратит женатый человек и жалуется ли он? Люди с PhD покупают фрукты? И тд
# 2. Разбейте данные на две выборки — по сумме трат каждого товара: 1 — больше медианы трат, 0— меньше. Сравните выборки между собой и сделайте вывод — на кого надо опираться при модификации товаров магазинам?
# 3. Проведите дополнительный анализ, который поможет дать больше информации для заказчика.

# %% [markdown]
# ## Загрузка данных

# %%
### импортируйте нужные библиотеки 
import pandas as pd
from plotly import express as px
from matplotlib import pyplot as plt
import seaborn as sns
import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('https://cdn.1t.ru/24/%D0%A4%D0%B0%D0%B9%D0%BB%D1%8B/DS/1_9/marketing_campaign.csv', sep='\t')

# %%
# ваш код здесь
display(df.sample(5))
print(f'До очистки данных - {df.shape[0]} строк и {df.shape[1]} столбцов ')
# Out:
#         ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 491     22        1976  Graduation       Divorced  46310.0        1         0
# 1965  6203        1947  Graduation       Together  74485.0        0         0
# 351    175        1986  Graduation        Married  71952.0        1         0
# 2118  6262        1962      Master         Single  72217.0        0         0
# 763   7573        1978         PhD         Single  31626.0        1         0
#
#      Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 491   03-12-2012       99       185  ...                  8             0
# 1965  24-08-2013       58       499  ...                  3             0
# 351   10-01-2013       93       656  ...                  4             1
# 2118  10-04-2013       93       816  ...                  2             0
# 763   10-05-2013       12        39  ...                  7             1
#
# ...

# %% [markdown]
# ## Описательный анализ данных

# %% [markdown]
# Рассмотрите данные — изучите медианы, средние, дисперсии и т.д.
#
# Что можете сказать о данных? Сделайте вывод.

# %%
# ваш код здесь
display(df.describe().T)
# Out:
#                       count          mean           std     min       25%  \
# ID                   2240.0   5592.159821   3246.662198     0.0   2828.25
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# ...

# %%
#  Выводим данные для object данных
display(df.describe(include='object').T)
# Out:
#                count unique         top  freq
# Education       2240      5  Graduation  1127
# Marital_Status  2240      8     Married   864
# Dt_Customer     2240    663  31-08-2012    12

# %%
for column in df.columns:
    if column != 'ID':
        print(f'Вывод соотношения для колонки {column}')
        display(df[column].value_counts(normalize=True))
        print('-'*100)
# Out:
# Вывод соотношения для колонки Year_Birth
# Year_Birth
# 1976    0.039732
# 1971    0.038839
# 1975    0.037054
# 1972    0.035268
# 1978    0.034375
# 1970    0.034375
# 1973    0.033036
# 1965    0.033036
# 1969    0.031696
# 1974    0.030804
# 1956    0.024554
# 1958    0.023661
# 1979    0.023661
# 1952    0.023214
# 1977    0.023214
# 1968    0.022768
# 1959    0.022768
# 1966    0.022321
# 1954    0.022321
# 1955    0.021875
# 1960    0.021875
# 1982    0.020089
# 1963    0.020089
# 1967    0.019643
# 1962    0.019643
# 1957    0.019196
# 1951    0.019196
# 1983    0.018750
# 1986    0.018750
# 1964    0.018750
# 1980    0.017411
# 1981    0.017411
# 1984    0.016964
# 1961    0.016071
# 1953    0.015625
# 1985    0.014286
# 1989    0.013393
# 1949    0.013393
# 1950    0.012946
# 1988    0.012946
# 1987    0.012054
# 1948    0.009375
# 1990    0.008036
# 1946    0.007143
# 1947    0.007143
# 1991    0.006696
# 1992    0.005804
# 1945    0.003571
# 1943    0.003125
# ...

# %% [markdown]
# **Вывод:**
# * Судя по минимальному году рождения клиента (1893, 1900 итд) - данные содержат нелогичные выбросы, самый молодой клиент - 1996 гр
# * 50% клиентов имеют образование Graduation
# * У 51% семей нет подростков
# * У 57% - нет детей, 40% - 1 ребенок, 2% - 2 детей
#
# * Значительные расходы в товарной корзине у исследуемых уходит на вино, на втором месте мясные продукты, на 3-ем золото, меньше всего тратят на сладости и фрукты
# * Покупки через ВЕБ имеют высокую конверсию, из 6 визитов на сайт - 4 уходят с покупками
# * Покупки онлайн составляют 44% от общего числа
# * Чаще покупают товары со скидкой 15%

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Предобработайте датасет — проверьте на наличие дубликатов и удалите, если они есть.

# %%
# ваш код здесь
display("Количество дубликатов перед удалением: ", df.duplicated().sum())
df.drop_duplicates(inplace=True)
display("Количество дубликатов после удаления: ", df.duplicated().sum())
# Out:
# 'Количество дубликатов перед удалением: '
# 0
# 'Количество дубликатов после удаления: '
# 0

# %% [markdown]
# ### Отсутствующие значения

# %% [markdown]
# Предобработайте датасет — проверьте на наличие NaN и удалите или заполните значения.

# %%
# ваш код здесь
pd.isnull(df).sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %% [markdown]
# * В поле дохода имеются пропуски, которые мы заполним медианным значением

# %%
#  Замена пропусков на медианные значения
df.fillna(
        {
            'Income': df.Income.median(),
        }, 
        inplace=True
    )
pd.isnull(df).sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %% [markdown]
# ### Изменение типа данных

# %% [markdown]
# Рассмотрев все данные, замените типы на нужные (при необходимости):
#
# - Если есть числа — на `int` или `float`
# - Если категории — можно оставить `object`

# %%
# ваш код здесь
display(df.dtypes)
# Out:
# ID                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# AcceptedCmp3             int64
# AcceptedCmp4             int64
# AcceptedCmp5             int64
# AcceptedCmp1             int64
# AcceptedCmp2             int64
# Complain                 int64
# Z_CostContact            int64
# Z_Revenue                int64
# Response                 int64
# dtype: object

# %% [markdown]
# **Вывод:**
# * Судя по типам данных, изменения не требуются, все ячейки датасета находятся с подходящими типами данных.
# * Пропуски по годовому доходу заполнил медианными значениями, что бы не терять остальные показатели датасета

# %% [markdown]
# ## Визуализация

# %%
# # ваш код здесь
df.hist(layout=(3, -1), bins=10, xrot=45, figsize=(20, 20), )
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'Year_Birth'}>,
#         <Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Kidhome'}>,
#         <Axes: title={'center': 'Teenhome'}>,
#         <Axes: title={'center': 'Recency'}>,
#         <Axes: title={'center': 'MntWines'}>,
#         <Axes: title={'center': 'MntFruits'}>,
#         <Axes: title={'center': 'MntMeatProducts'}>],
#        [<Axes: title={'center': 'MntFishProducts'}>,
#         <Axes: title={'center': 'MntSweetProducts'}>,
#         <Axes: title={'center': 'MntGoldProds'}>,
#         <Axes: title={'center': 'NumDealsPurchases'}>,
#         <Axes: title={'center': 'NumWebPurchases'}>,
#         <Axes: title={'center': 'NumCatalogPurchases'}>,
#         <Axes: title={'center': 'NumStorePurchases'}>,
#         <Axes: title={'center': 'NumWebVisitsMonth'}>,
#         <Axes: title={'center': 'AcceptedCmp3'}>],
#        [<Axes: title={'center': 'AcceptedCmp4'}>,
# ...

# %%
for column in df.columns:
    if (column not in ['ID', 'Kidhome', 'Teenhome', 'Recency', 'Education', 'Dt_Customer', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'] 
            and not column.startswith('Accepted')):
    # if column != 'ID':
        plt.figure(figsize=(15, 5))
        sns.boxplot(df[column], orient='h')
        plt.show()

# %% [markdown]
# * В данных имеются выбросы, которые при проведении глубокого изучения стоит дополнительно обработать

# %%
for column in df.columns:
    if df[column].dtype == 'object' and column != 'Dt_Customer':
        tmp_vc = df[column].value_counts()
        plt.figure(figsize=(15, 5))
        sns.barplot(x=tmp_vc.index, y=tmp_vc)
        plt.title(column)
        plt.show()

# %% [markdown]
# * Наибольшее количество исследуемых имеют образование Graduation
# * Наибольшее количество исследуемых замужем/женаты

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(df.select_dtypes(['int', 'float']).corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * Явных признаков кореляции данных нет за исключением 72% кореляции заказов мясных продуктов через каталог

# %%
# Сначала найдем средний доход для каждого количества детей (Kidhome)
grouped_df = df.groupby(['Kidhome'])['Income'].mean().reset_index()

# Теперь можно построить гистограмму
plt.figure(figsize=(8,6))
sns.barplot(x='Kidhome', y='Income', data=grouped_df, palette='mako')

plt.title('Средний доход в зависимости от количества детей')
plt.xlabel('Количество детей')
plt.ylabel('Средний доход')
plt.show()

# %% [markdown]
# * Уровень дохода выше в семье где нет детей

# %%
# Группируем данные по образованию и вычисляем средний доход
grouped = df.groupby('Education')['Income'].mean().reset_index()

# Строим гистограмму
fig = px.bar(grouped, x='Education', y='Income', title='Средний доход в зависимости от образования')

fig.show()
# Out:
# <div>                            <div id="9315846a-279f-419c-a18d-380f447598ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9315846a-279f-419c-a18d-380f447598ba")) {                    Plotly.newPlot(                        "9315846a-279f-419c-a18d-380f447598ba",                        [{"alignmentgroup":"True","hovertemplate":"Education=%{x}\u003cbr\u003eIncome=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2n Cycle","Basic","Graduation","Master","PhD"],"xaxis":"x","y":[47688.58374384236,20306.25925925926,52707.30567879326,52896.77702702703,56096.30349794239],"yaxis":"y","type":"bar"}], 
# ...

# %% [markdown]
# * За исключением образования Basic уровень дохода не зависит в остальных группах от уровня образования.

# %%
# Создание графика
fig = px.histogram(df, x="Education", color="Kidhome", 
                   barmode="group",
                   title="Распределение образования с учетом количества детей")

fig.show()
# Out:
# <div>                            <div id="034a9cfd-dd43-49de-a492-4c4955fd1296" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("034a9cfd-dd43-49de-a492-4c4955fd1296")) {                    Plotly.newPlot(                        "034a9cfd-dd43-49de-a492-4c4955fd1296",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Kidhome=0\u003cbr\u003eEducation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":["Graduation","Graduation","Master","Graduation","Basic","Graduation","Graduation","PhD","Graduation","Master","Graduation","PhD","PhD","Graduation","Graduation","PhD",
# ...

# %% [markdown]
# * Больше всего семей без детей у тех, у кого образование Graduation
# * В бОльшей части семей без образования имеются дети, чего не скажешь в остальных группах образования

# %% [markdown]
# **Вывод:**
# * В данных имеются выбросы, которые при проведении глубокого изучения стоит дополнительно обработать
# * Больше всего семей без детей у тех, у кого образование Graduation
# * В бОльшей части семей без образования имеются дети, чего не скажешь в остальных группах образования
# * За исключением образования Basic уровень дохода не зависит в остальных группах от уровня образования.
# * Уровень дохода выше в семье где нет детей
# * Явных признаков кореляции данных нет за исключением 72% кореляции заказов мясных продуктов через каталог
# * Наибольшее количество исследуемых имеют образование Graduation
# * Наибольшее количество исследуемых замужем/женаты

# %% [markdown]
# ## Задание от заказчика

# %% [markdown]
# 1. Сколько в среднем клиенты тратят на каждый тип товара? На какой товар надо сделать акцент?
# 2. Какой средний возраст покупателя? Зависит ли возраст клиента от его покупок во всех категориях?
# 3. Тратят ли клиент больше денег, если у него много детей и иждивенцев?
# 4. Зависят ли покупки от образования? Что предпочитают люди чаще покупать в зависимости от образования?
# 5. Женатые люди тратят больше или меньше денег на покупку золота?
# 6. Люди, которые покупают товар на сайте чаще берут что-то со скидкой?
# 7. Зависит ли жалоба клиента от его трат?
# 8. Люди, принявшие предложение о покупке лишь в последней компании тратят больше, чем люди, принявшие сразу предложение первой компании?

# %%
# ваш код здесь
products = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
mean_expenses = df[products].mean()
mean_expenses = mean_expenses.sort_values(ascending=False)
display(mean_expenses)

plt.figure(figsize=(10, 6))
sns.barplot(x=mean_expenses.index, y=mean_expenses.values, hue=mean_expenses.values, palette='viridis')
plt.xlabel('Тип товара')
plt.ylabel('Средние затраты')
plt.title('Средние затраты на каждый тип товара')
plt.xticks(rotation=45) # чтобы подписи по оси x были читабельными
plt.show()

# Находим корреляции возраста с затратами на товары
correlations = df[['Year_Birth'] + products].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(correlations, annot=True, cmap='coolwarm', center=0)
plt.title('Корреляция возраста с затратами на разные категории товаров')
plt.xticks(rotation=45)
plt.show()
# Out:
# MntWines            303.935714
# MntMeatProducts     166.950000
# MntGoldProds         44.021875
# MntFishProducts      37.525446
# MntSweetProducts     27.062946
# MntFruits            26.302232
# dtype: float64

# %%
product_columns = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

melted_df = df.melt(id_vars='Education', value_vars=product_columns, var_name='Product', value_name='Quantity')

grouped_df = melted_df.groupby(['Education', 'Product'])['Quantity'].sum().reset_index()

fig = px.bar(grouped_df, x='Education', y='Quantity', color='Product', 
             title="Зависимость типов товаров от образования",
             labels={'Quantity':'Количество товара', 'Product':'Тип товара'})

fig.show()
# Out:
# <div>                            <div id="309b30a4-95b9-41be-aa89-a84c87b16f23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("309b30a4-95b9-41be-aa89-a84c87b16f23")) {                    Plotly.newPlot(                        "309b30a4-95b9-41be-aa89-a84c87b16f23",                        [{"alignmentgroup":"True","hovertemplate":"\u0422\u0438\u043f \u0442\u043e\u0432\u0430\u0440\u0430=MntFishProducts\u003cbr\u003eEducation=%{x}\u003cbr\u003e\u041a\u043e\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e \u0442\u043e\u0432\u0430\u0440\u0430=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MntFishProducts","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"MntFishProducts","offsetgroup":"MntFishProducts","orientation":"v","showlege
# ...

# %%
# Вычисляем средний возраст
df['Age'] = datetime.datetime.now().year - df['Year_Birth']
# display(df.Age)
print(f"Средний возраст покупателей: {df['Age'].mean()}")

product_columns = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

for product in product_columns:
    avg_age_product = df[df[product] > 0]['Age'].mean()
    print(f"Средний возраст покупателей {product}: {avg_age_product}")
# Out:
# Средний возраст покупателей: 55.19419642857143
# Средний возраст покупателей MntWines: 55.24202963628199
# Средний возраст покупателей MntFruits: 54.96141304347826
# Средний возраст покупателей MntMeatProducts: 55.19696292987941
# Средний возраст покупателей MntFishProducts: 54.89331896551724
# Средний возраст покупателей MntSweetProducts: 54.626029654036245
# Средний возраст покупателей MntGoldProds: 55.142267094997706

# %%
mnt_columns = [col for col in df.columns if 'Mnt' in col]
df['TotalSpent'] = df[mnt_columns].sum(axis=1)

grouped = df.groupby('Kidhome')['TotalSpent'].mean()
print(grouped)

grouped.plot(kind='bar')
plt.xlabel('Зависимость расходов от количества детей')
plt.ylabel('Средняя сумма расходов')
plt.title('Величина расходов в зависимости от количества детей')
plt.show()
# Out:
# Kidhome
# 0    901.260634
# 1    205.434928
# 2    145.250000
# Name: TotalSpent, dtype: float64

# %%
mnt_columns = [col for col in df.columns if 'Mnt' in col]

columns_to_consider = mnt_columns + ['Education']

df2 = df[columns_to_consider]

grouped = df2.groupby('Education')[mnt_columns].mean()

display(grouped)

plt.figure(figsize=(10, 6))
sns.heatmap(grouped, annot=True, fmt=".1f")
plt.title('Средние затраты на различные типы товаров в зависимости от образования')
plt.show()
# Out:
#               MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Education
# 2n Cycle    198.182266  28.955665       141.256158        47.482759
# Basic         7.240741  11.111111        11.444444        17.055556
# Graduation  284.268855  30.774623       179.488909        43.149956
# Master      333.075676  21.654054       163.378378        32.100000
# PhD         404.495885  20.049383       168.602881        26.728395
#
#             MntSweetProducts  MntGoldProds
# Education
# 2n Cycle           34.251232     46.399015
# Basic              12.111111     22.833333
# Graduation         31.367347     50.849157
# Master             21.175676     40.397297
# PhD                20.222222     32.310700

# %% [markdown]
# * От уровня образования зависят расходы, чаще люди покупают вино и мясные продукты

# %%
average_gold_spent_marital_status = df.groupby('Marital_Status')['MntGoldProds'].mean()
display(average_gold_spent_marital_status)
# Out:
# Marital_Status
# Absurd      204.000000
# Alone        27.000000
# Divorced     46.288793
# Married      42.822917
# Single       43.729167
# Together     42.994828
# Widow        56.766234
# YOLO         42.000000
# Name: MntGoldProds, dtype: float64

# %% [markdown]
# * Семьи в статусе Absurd берут золото значительно больше остальных

# %%
compare_complain_spent = df.groupby('Complain')['TotalSpent'].mean()
display(compare_complain_spent)
# Out:
# Complain
# 0    607.968905
# 1    376.428571
# Name: TotalSpent, dtype: float64

# %% [markdown]
# * Люди, которые не жаловались, чаще покупают в магазимне

# %% [markdown]
# **Вывод:**
# * В среднем на вино тратят больше всего денег, а на фрукты и сладости - меньше, уделить больше сил на продажу сладостей и фруктов
# * Средний возраст покупателей: 55.19419642857143, покупаемые товары не зависят от возраста.
# * Люди с образованием Graduation тратят больше всего денег в магазине
# * Семьи, где нет детей, тратят больше денег.
# * От уровня образования зависят расходы, чаще люди покупают вино и мясные продукты
# * Семьи в статусе Absurd берут золото значительно больше остальных
# * Люди, которые не жаловались, чаще покупают в магазине

# %% [markdown]
# ### ЗАДАНИЕ ПРО
#
# 1. Разбейте данные на несколько выборок: по образованию, по уровню заработка и по семейному статусу. Опишите все эти выборки и скажите — отличаются ли они между собой? Опишите общие закономерности для каждого типа — на что чаще тратит женатый человек и жалуется ли он? Люди с PhD покупают фрукты? И тд
# 2. Разбейте данные на две выборки — по сумме трат каждого товара: 1 — больше медианы трат, 0 — меньше. Сравните выборки между собой и сделайте вывод — на кого надо опираться при модификации товаров магазинам?
# 3. Проведите дополнительный анализ, который поможет дать больше информации для заказчика.

# %%
# ваш код здесь

# %% [markdown]
# **Вывод:**

# %% [markdown]
# # Общий вывод

# %% [markdown]
# Опишите данные и результат исследования, основываясь на предыдущих шагах:
